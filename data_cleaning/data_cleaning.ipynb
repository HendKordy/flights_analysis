# %%
import numpy as np
import pandas as pd

# %%
df_train = pd.read_excel('flights.xlsx')
df = pd.read_excel('../data/test_set/flights_test.xlsx')

# %%
df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
df.shape
# Out:
# (2671, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2671 non-null   object
#  1   Date_of_Journey  2671 non-null   object
#  2   Source           2671 non-null   object
#  3   Destination      2671 non-null   object
#  4   Route            2671 non-null   object
#  5   Dep_Time         2671 non-null   object
#  6   Arrival_Time     2671 non-null   object
#  7   Duration         2671 non-null   object
#  8   Total_Stops      2671 non-null   object
#  9   Additional Info  2671 non-null   object
# dtypes: object(10)
# memory usage: 208.8+ KB

# %% [markdown]
# ## Convert columns type

# %%
###convert time to DateTime type
df['Date_of_Journey']=pd.to_datetime(df['Date_of_Journey'], format = "%d/%m/%Y")

# %%
# divide Dep_Time to hours and minutes 

def get_dep_hour(x):
    return x.split(sep = ':')[0]

def get_dep_min(x):
    return x.split(sep = ':')[1]

df['dep_hour'] = df.Dep_Time.apply(get_dep_hour).astype(int)
df['dep_min'] = df.Dep_Time.apply(get_dep_min).astype(int)

# %%
#divide years, months, days of datetime dtype
df['journey_year']=df['Date_of_Journey'].dt.year
df['journey_month']=df['Date_of_Journey'].dt.month
df['journey_day']=df['Date_of_Journey'].dt.day

# %%
#Add columns: arrival hours, minutes, and Arrived_next_day
def get_arr_hour(x):
    time = x.split(sep= " ")[0]
    return time.split(sep = ":")[0]
def get_arr_min(x):
    time = x.split(sep= " ")[0]
    return time.split(sep = ":")[1]


def arrived_next_day(x):
    values = x.split(sep = " ")
    return len(values) > 2



df['Arrival_hour'] = df.Arrival_Time.apply(get_arr_hour).astype(int)
df['Arrival_min'] = df.Arrival_Time.apply(get_arr_min).astype(int)
df['Arrived_next_day'] = df.Arrival_Time.apply(arrived_next_day)

# %%
#create columns for 1- hours, 2- mins, 3- duration converted into mins 

def get_hour(x): 
    if "h" not in x:
        return 0
    return x.split(sep = "h")[0]

def get_min(x):
    if "m" not in x: 
        return 0
    return x.split(sep = "m")[0].split()[-1]

def convert_to_mins(x):
    hours = int(get_hour(x))
    mins = int(get_min(x))
    return mins + hours * 60

df['duration_hours'] = df['Duration'].apply(get_hour)
df['duration_mins'] = df['Duration'].apply(get_min)
df['Duration_in_mins'] = df['Duration'].apply(convert_to_mins)

# %% [markdown]
# weekdays = Mon = 0, Tue =1, Wed = 2, Thur = 3, Fri = 4, Sat = 5, Sun = 6

# %%
#add weekday 
df['weekday'] = df.Date_of_Journey.dt.dayofweek

# %% [markdown]
# ## Handling null values

# %%
#check for null values
df.isnull().sum()
# Out:
# Airline             0
# Date_of_Journey     0
# Source              0
# Destination         0
# Route               0
# Dep_Time            0
# Arrival_Time        0
# Duration            0
# Total_Stops         0
# Additional Info     0
# dep_hour            0
# dep_min             0
# journey_year        0
# journey_month       0
# journey_day         0
# Arrival_hour        0
# Arrival_min         0
# Arrived_next_day    0
# duration_hours      0
# duration_mins       0
# Duration_in_mins    0
# weekday             0
# dtype: int64

# %%
#check the instance with NaN
df1 = df[df.isna().any(axis=1)]
df1
# Out:
# Empty DataFrame
# Columns: [Airline, Date_of_Journey, Source, Destination, Route, Dep_Time, Arrival_Time, Duration, Total_Stops, Additional Info, dep_hour, dep_min, journey_year, journey_month, journey_day, Arrival_hour, Arrival_min, Arrived_next_day, duration_hours, duration_mins, Duration_in_mins, weekday]
# Index: []
#
# [0 rows x 22 columns]

# %%
#drop the instance with NaN
df.dropna(inplace=True)

# %%
#renaming Additional Info column to be able to access .value_counts()
df.rename({'Additional Info': 'additional_info'}, axis=1, inplace=True)

# %%
#the feature [additional_info] contains 'No info' which counts as nulls 
df.additional_info.value_counts()
# Out:
# No info                         2148
# In-flight meal not included      444
# No check-in baggage included      76
# 1 Long layover                     1
# Business class                     1
# Change airports                    1
# Name: additional_info, dtype: int64

# %%
#since 'No info' represent approximately 76% of the column and it appears to be missing at random, but we're waiting for more info. 
#meanwhile, we'll keep it but will not include it in the training set

# %% [markdown]
# ## Check for duplicates

# %%
#check for duplicates
df.duplicated().value_counts()
# Out:
# False    2645
# True       26
# dtype: int64

# %%
#view duplicated rows
df[df.duplicated()]
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 294         Jet Airways      2019-06-12     Delhi      Cochin
# 794         Jet Airways      2019-06-12     Delhi      Cochin
# 909              IndiGo      2019-03-24  Banglore   New Delhi
# 974           Air India      2019-06-12   Kolkata    Banglore
# 1011        Jet Airways      2019-05-09     Delhi      Cochin
# 1033  Multiple carriers      2019-05-15     Delhi      Cochin
# 1044              GoAir      2019-03-24  Banglore   New Delhi
# 1233        Jet Airways      2019-06-06     Delhi      Cochin
# 1504          Air India      2019-06-15     Delhi      Cochin
# 1537        Jet Airways      2019-06-06     Delhi      Cochin
# 1752  Multiple carriers      2019-05-21     Delhi      Cochin
# 1753        Jet Airways      2019-05-18     Delhi      Cochin
# 1783          Air India      2019-03-12  Banglore   New Delhi
# 1876          Air India      2019-04-01   Kolkata    Banglore
# 1962  Multiple carriers      2019-06-15     Delhi      Cochin
# 2007        Jet Airways      2019-06-24     Delhi      Cochin
# 2042          Air India      2019-03-09  Banglore   New Delhi
# 2083          Air India      2019-06-15     Delhi      Cochin
# 2095        Jet Airways      2019-06-01     Delhi      Cochin
# 2171        Jet Airways      2019-05-21     Delhi      Cochin
# 2310        Jet Airways      2019-03-27     Delhi      Cochin
# 2536          Air India      2019-06-03     Delhi      Cochin
# 2553        Jet Airways      2019-06-15     Delhi      Cochin
# 2560  Multiple carriers      2019-06-03     Delhi      Cochin
# 2582          Air India      2019-05-12   Kolkata    Banglore
# 2583             IndiGo      2019-03-24  Banglore   New Delhi
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 294   DEL → JAI → BOM → COK    05:30  04:25 13 Jun  22h 55m     2 stops
# 794   DEL → JAI → BOM → COK    05:30  04:25 13 Jun  22h 55m     2 stops
# 909               BLR → DEL    20:00         22:55   2h 55m    non-stop
# 974   CCU → DEL → AMD → BLR    07:00  05:25 13 Jun  22h 25m     2 stops
# 1011  DEL → JAI → BOM → COK    05:30  04:25 10 May  22h 55m     2 stops
# 1033        DEL → BOM → COK    07:30         19:15  11h 45m      1 stop
# 1044              BLR → DEL    20:55         23:50   2h 55m    non-stop
# 1233  DEL → JAI → BOM → COK    05:30  04:25 07 Jun  22h 55m     2 stops
# 1504  DEL → GOI → BOM → COK    22:00  19:15 16 Jun  21h 15m     2 stops
# 1537  DEL → NAG → BOM → COK    06:45  04:25 07 Jun  21h 40m     2 stops
# 1752        DEL → BOM → COK    07:30         19:15  11h 45m      1 stop
# 1753  DEL → AMD → BOM → COK    23:05  19:00 19 May  19h 55m     2 stops
# 1783  BLR → CCU → GAU → DEL    05:50         22:10  16h 20m     2 stops
# 1876  CCU → DEL → COK → BLR    07:00  01:20 02 Apr  18h 20m     2 stops
# 1962        DEL → BOM → COK    10:00         21:00      11h      1 stop
# 2007  DEL → JAI → BOM → COK    09:40  04:25 25 Jun  18h 45m     2 stops
# 2042  BLR → BOM → AMD → DEL    17:25  23:55 13 Mar  30h 30m     2 stops
# 2083  DEL → HYD → BOM → COK    13:15  19:15 16 Jun      30h     2 stops
# 2095  DEL → NAG → BOM → COK    14:35  04:25 02 Jun  13h 50m     2 stops
# 2171  DEL → JAI → BOM → COK    09:40  12:35 22 May  26h 55m     2 stops
# 2310  DEL → MAA → BOM → COK    05:10  04:25 28 Mar  23h 15m     2 stops
# 2536  DEL → GOI → BOM → COK    22:00  19:15 04 Jun  21h 15m     2 stops
# 2553  DEL → JAI → BOM → COK    05:30         19:00  13h 30m     2 stops
# 2560        DEL → BOM → COK    13:00  01:30 04 Jun  12h 30m      1 stop
# 2582  CCU → BOM → GOI → BLR    16:50  05:35 13 May  12h 45m     2 stops
# 2583              BLR → DEL    18:55         21:45   2h 50m    non-stop
#
#                   additional_info  ...  journey_year  journey_month  \
# 294                       No info  ...          2019              6
# 794   In-flight meal not included  ...          2019              6
# 909                       No info  ...          2019              3
# 974                       No info  ...          2019              6
# 1011                      No info  ...          2019              5
# 1033                      No info  ...          2019              5
# 1044                      No info  ...          2019              3
# 1233                      No info  ...          2019              6
# 1504                      No info  ...          2019              6
# 1537  In-flight meal not included  ...          2019              6
# 1752                      No info  ...          2019              5
# 1753                      No info  ...          2019              5
# 1783                      No info  ...          2019              3
# 1876                      No info  ...          2019              4
# 1962                      No info  ...          2019              6
# 2007                      No info  ...          2019              6
# 2042                      No info  ...          2019              3
# 2083                      No info  ...          2019              6
# 2095  In-flight meal not included  ...          2019              6
# 2171                      No info  ...          2019              5
# 2310  In-flight meal not included  ...          2019              3
# 2536                      No info  ...          2019              6
# 2553                      No info  ...          2019              6
# 2560                      No info  ...          2019              6
# 2582                      No info  ...          2019              5
# 2583                      No info  ...          2019              3
#
#       journey_day  Arrival_hour  Arrival_min  Arrived_next_day  \
# 294            12             4           25              True
# 794            12             4           25              True
# 909            24            22           55             False
# 974            12             5           25              True
# 1011            9             4           25              True
# 1033           15            19           15             False
# 1044           24            23           50             False
# 1233            6             4           25              True
# 1504           15            19           15              True
# 1537            6             4           25              True
# 1752           21            19           15             False
# 1753           18            19            0              True
# 1783           12            22           10             False
# 1876            1             1           20              True
# 1962           15            21            0             False
# 2007           24             4           25              True
# 2042            9            23           55              True
# 2083           15            19           15              True
# 2095            1             4           25              True
# 2171           21            12           35              True
# 2310           27             4           25              True
# 2536            3            19           15              True
# 2553           15            19            0             False
# 2560            3             1           30              True
# 2582           12             5           35              True
# 2583           24            21           45             False
#
#       duration_hours  duration_mins Duration_in_mins weekday
# 294               22             55             1375       2
# 794               22             55             1375       2
# 909                2             55              175       6
# 974               22             25             1345       2
# 1011              22             55             1375       3
# 1033              11             45              705       2
# 1044               2             55              175       6
# 1233              22             55             1375       3
# 1504              21             15             1275       5
# 1537              21             40             1300       3
# 1752              11             45              705       1
# 1753              19             55             1195       5
# 1783              16             20              980       1
# 1876              18             20             1100       0
# 1962              11              0              660       5
# 2007              18             45             1125       0
# 2042              30             30             1830       5
# 2083              30              0             1800       5
# 2095              13             50              830       5
# 2171              26             55             1615       1
# 2310              23             15             1395       2
# 2536              21             15             1275       0
# 2553              13             30              810       5
# 2560              12             30              750       0
# 2582              12             45              765       6
# 2583               2             50              170       6
#
# [26 rows x 22 columns]

# %%
#drop duplicated rows
df.drop_duplicates(keep='first',inplace=True)

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Define a function to return arrival and departure hours as parts of the day

# %%
#define hours of the day
def ptday(x):
    if x>=00 and x<=4:
        return 'late night'
    elif x>4 and x<=8:
        return 'early morning'
    elif x>8 and x<=12:
        return 'morning'
    elif x>12 and x<=16:
        return 'After noon'
    elif x>16 and x<=20:
        return'evening'
    elif x>20 and x<=23:
        return 'night'

# %%
#apply the function to arrival hours and departure hours
df['arrival_period']=df['Arrival_hour'].apply(ptday)
df['departure_period']=df['dep_hour'].apply(ptday)

# %% [markdown]
# ## Drop redundant columns

# %%
#since we created new columns that extracted info from the following columns, we will drop them
df.drop(['Date_of_Journey'], axis=1, inplace=True)
df.drop(['Dep_Time'], axis=1, inplace=True)
df.drop('Arrival_Time', axis = 1, inplace = True)
# df.drop('duration_mins', axis = 1, inplace = True)
df.drop(['Duration'], axis=1, inplace=True)


#Route contains the name of cities and the number of stops. This info is already given in the Total_Stops and Destination and Source columns
#thus, we will drop Route
# df.drop(['Route'], axis=1, inplace=True)

# %%
df.head(10)
# Out:
#              Airline    Source Destination            Route Total_Stops  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR      1 stop
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      1 stop
# 4           Air Asia  Banglore       Delhi        BLR → DEL    non-stop
# 5        Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# 6          Air India  Banglore   New Delhi  BLR → TRV → DEL      1 stop
# 7             IndiGo   Kolkata    Banglore  CCU → HYD → BLR      1 stop
# 8             IndiGo   Kolkata    Banglore        CCU → BLR    non-stop
# 9        Jet Airways   Kolkata    Banglore  CCU → BOM → BLR      1 stop
#
#                additional_info  dep_hour  dep_min  journey_year  \
# 0                      No info        17       30          2019
# 1                      No info         6       20          2019
# 2  In-flight meal not included        19       15          2019
# 3                      No info         8        0          2019
# 4                      No info        23       55          2019
# 5  In-flight meal not included        18       15          2019
# 6                      No info         7       30          2019
# 7                      No info        15       15          2019
# 8                      No info        10       10          2019
# 9                      No info        16       30          2019
#
#    journey_month  journey_day  Arrival_hour  Arrival_min  Arrived_next_day  \
# 0              6            6             4           25              True
# 1              5           12            10           20             False
# 2              5           21            19            0              True
# 3              5           21            21            0             False
# 4              6           24             2           45              True
# 5              6           12            12           35              True
# 6              3           12            22           35             False
# 7              5            1            20           30             False
# 8              3           15            12           55             False
# 9              5           18            22           35             False
#
#   duration_hours duration_mins  Duration_in_mins  weekday arrival_period  \
# 0             10            55               655        3     late night
# 1              4             0               240        6        morning
# 2             23            45              1425        1        evening
# 3             13             0               780        1          night
# 4              2            50               170        0     late night
# 5             18            20              1100        2        morning
# 6             15             5               905        1          night
# 7              5            15               315        2        evening
# 8              2            45               165        4        morning
# 9              6             5               365        5          night
#
#   departure_period
# 0          evening
# 1    early morning
# 2          evening
# 3    early morning
# 4            night
# 5          evening
# 6    early morning
# 7       After noon
# 8          morning
# 9       After noon

# %% [markdown]
# ## Rearrange and rename columns

# %% [markdown]
# **Renaming columns**

# %%
df.rename(columns={'Airline': "airline", 'Source':'embarked', 'Destination':'destination','Price':'price','Total_Stops':'stops'}, inplace=True)

# %% [markdown]
# **Rearranging columns**

# %%
df = df[['airline', 'embarked', 'destination', 'Route', 'stops',
       'journey_year',
       'journey_month', 'journey_day', 'weekday', 'dep_hour', 'dep_min', 'departure_period',  'Arrival_hour', 'Arrival_min', 'arrival_period',
       'Arrived_next_day',  'duration_hours', 'duration_mins',
       'Duration_in_mins' ,'additional_info']]

# %% [markdown]
# ## Save cleaned data to new file

# %%
df.to_csv("./df_cleaned_test.csv", index = False)

# %%
cleaned = pd.read_csv("./df_cleaned_test.csv")
cleaned
# Out:
#                 airline  embarked destination            Route     stops  \
# 0           Jet Airways     Delhi      Cochin  DEL → BOM → COK    1 stop
# 1                IndiGo   Kolkata    Banglore  CCU → MAA → BLR    1 stop
# 2           Jet Airways     Delhi      Cochin  DEL → BOM → COK    1 stop
# 3     Multiple carriers     Delhi      Cochin  DEL → BOM → COK    1 stop
# 4              Air Asia  Banglore       Delhi        BLR → DEL  non-stop
# ...                 ...       ...         ...              ...       ...
# 2640          Air India   Kolkata    Banglore  CCU → DEL → BLR    1 stop
# 2641             IndiGo   Kolkata    Banglore        CCU → BLR  non-stop
# 2642        Jet Airways     Delhi      Cochin  DEL → BOM → COK    1 stop
# 2643          Air India     Delhi      Cochin  DEL → BOM → COK    1 stop
# 2644  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    1 stop
#
#       journey_year  journey_month  journey_day  weekday  dep_hour  dep_min  \
# 0             2019              6            6        3        17       30
# 1             2019              5           12        6         6       20
# 2             2019              5           21        1        19       15
# 3             2019              5           21        1         8        0
# 4             2019              6           24        0        23       55
# ...            ...            ...          ...      ...       ...      ...
# 2640          2019              6            6        3        20       30
# 2641          2019              3           27        2        14       20
# 2642          2019              3            6        2        21       50
# 2643          2019              3            6        2         4        0
# 2644          2019              6           15        5         4       55
#
#      departure_period  Arrival_hour  Arrival_min arrival_period  \
# 0             evening             4           25     late night
# 1       early morning            10           20        morning
# 2             evening            19            0        evening
# 3       early morning            21            0          night
# 4               night             2           45     late night
# ...               ...           ...          ...            ...
# 2640          evening            20           25        evening
# 2641       After noon            16           55     After noon
# 2642            night             4           25     late night
# 2643       late night            19           15        evening
# 2644       late night            19           15        evening
#
#       Arrived_next_day  duration_hours  duration_mins  Duration_in_mins  \
# 0                 True              10             55               655
# 1                False               4              0               240
# 2                 True              23             45              1425
# 3                False              13              0               780
# 4                 True               2             50               170
# ...                ...             ...            ...               ...
# 2640              True              23             55              1435
# 2641             False               2             35               155
# 2642              True               6             35               395
# 2643             False              15             15               915
# 2644             False              14             20               860
#
#                   additional_info
# 0                         No info
# 1                         No info
# 2     In-flight meal not included
# 3                         No info
# 4                         No info
# ...                           ...
# 2640                      No info
# 2641                      No info
# 2642                      No info
# 2643                      No info
# 2644                      No info
#
# [2645 rows x 20 columns]
