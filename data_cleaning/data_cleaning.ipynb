# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('flights.xlsx')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3898
# 1    05:50         13:15   7h 25m     2 stops         No info   7663
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13883
# 3    18:05         23:30   5h 25m      1 stop         No info   6219
# 4    16:50         21:35   4h 45m      1 stop         No info  13303

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# ## Convert columns type

# %%
###convert time to DateTime type
df['Date_of_Journey']=pd.to_datetime(df['Date_of_Journey'], format = "%d/%m/%Y")

# %%
# divide Dep_Time to hours and minutes 

def get_dep_hour(x):
    return x.split(sep = ':')[0]

def get_dep_min(x):
    return x.split(sep = ':')[1]

df['dep_hour'] = df.Dep_Time.apply(get_dep_hour).astype(int)
df['dep_min'] = df.Dep_Time.apply(get_dep_min).astype(int)

# %%
#divide years, months, days of datetime dtype
df['journey_year']=df['Date_of_Journey'].dt.year
df['journey_month']=df['Date_of_Journey'].dt.month
df['journey_day']=df['Date_of_Journey'].dt.day

# %%
#Add columns: arrival hours, minutes, and Arrived_next_day
def get_arr_hour(x):
    time = x.split(sep= " ")[0]
    return time.split(sep = ":")[0]
def get_arr_min(x):
    time = x.split(sep= " ")[0]
    return time.split(sep = ":")[1]


def arrived_next_day(x):
    values = x.split(sep = " ")
    return len(values) > 2



df['Arrival_hour'] = df.Arrival_Time.apply(get_arr_hour).astype(int)
df['Arrival_min'] = df.Arrival_Time.apply(get_arr_min).astype(int)
df['Arrived_next_day'] = df.Arrival_Time.apply(arrived_next_day)

# %%
#create columns for 1- hours, 2- mins, 3- duration converted into mins 

def get_hour(x): 
    if "h" not in x:
        return 0
    return x.split(sep = "h")[0]

def get_min(x):
    if "m" not in x: 
        return 0
    return x.split(sep = "m")[0].split()[-1]

def convert_to_mins(x):
    hours = int(get_hour(x))
    mins = int(get_min(x))
    return mins + hours * 60

df['duration_hours'] = df['Duration'].apply(get_hour)
df['duration_mins'] = df['Duration'].apply(get_min)
df['Duration_in_mins'] = df['Duration'].apply(convert_to_mins)

# %% [markdown]
# weekdays = Mon = 0, Tue =1, Wed = 2, Thur = 3, Fri = 4, Sat = 5, Sun = 6

# %%
#add weekday 
df['weekday'] = df.Date_of_Journey.dt.dayofweek

# %% [markdown]
# ## Handling null values

# %%
#check for null values
df.isnull().sum()
# Out:
# Airline             0
# Date_of_Journey     0
# Source              0
# Destination         0
# Route               1
# Dep_Time            0
# Arrival_Time        0
# Duration            0
# Total_Stops         1
# Additional Info     0
# Price               0
# dep_hour            0
# dep_min             0
# journey_year        0
# journey_month       0
# journey_day         0
# Arrival_hour        0
# Arrival_min         0
# Arrived_next_day    0
# duration_hours      0
# duration_mins       0
# Duration_in_mins    0
# weekday             0
# dtype: int64

# %%
#check the instance with NaN
df1 = df[df.isna().any(axis=1)]
df1
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India      2019-05-06  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional Info  ...  journey_year  \
# 9039  09:25 07 May  23h 40m         NaN         No info  ...          2019
#
#       journey_month  journey_day  Arrival_hour  Arrival_min  Arrived_next_day  \
# 9039              5            6             9           25              True
#
#       duration_hours  duration_mins  Duration_in_mins weekday
# 9039              23             40              1420       0
#
# [1 rows x 23 columns]

# %%
#drop the instance with NaN
df.dropna(inplace=True)

# %%
#renaming Additional Info column to be able to access .value_counts()
df.rename({'Additional Info': 'additional_info'}, axis=1, inplace=True)

# %%
#the feature [additional_info] contains 'No info' which counts as nulls 
df.additional_info.value_counts()
# Out:
# No info                         8344
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: additional_info, dtype: int64

# %%
#since 'No info' represent approximately 76% of the column and it appears to be missing at random, but we're waiting for more info. 
#meanwhile, we'll keep it but will not include it in the training set

# %% [markdown]
# ## Check for duplicates

# %%
#check for duplicates
df.duplicated().value_counts()
# Out:
# False    10462
# True       220
# dtype: int64

# %%
#view duplicated rows
df[df.duplicated()]
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 683    Jet Airways      2019-06-01     Delhi      Cochin
# 1061     Air India      2019-05-21     Delhi      Cochin
# 1348     Air India      2019-05-18     Delhi      Cochin
# 1418   Jet Airways      2019-06-06     Delhi      Cochin
# 1674        IndiGo      2019-03-24  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10594  Jet Airways      2019-06-27     Delhi      Cochin
# 10616  Jet Airways      2019-06-01     Delhi      Cochin
# 10634  Jet Airways      2019-06-06     Delhi      Cochin
# 10672  Jet Airways      2019-06-27     Delhi      Cochin
# 10673  Jet Airways      2019-05-27     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 683    DEL → NAG → BOM → COK    14:35  04:25 02 Jun  13h 50m     2 stops
# 1061   DEL → GOI → BOM → COK    22:00  19:15 22 May  21h 15m     2 stops
# 1348   DEL → HYD → BOM → COK    17:15  19:15 19 May      26h     2 stops
# 1418   DEL → JAI → BOM → COK    05:30  04:25 07 Jun  22h 55m     2 stops
# 1674               BLR → DEL    18:25         21:20   2h 55m    non-stop
# ...                      ...      ...           ...      ...         ...
# 10594  DEL → AMD → BOM → COK    23:05  12:35 28 Jun  13h 30m     2 stops
# 10616  DEL → JAI → BOM → COK    09:40  12:35 02 Jun  26h 55m     2 stops
# 10634  DEL → JAI → BOM → COK    09:40  12:35 07 Jun  26h 55m     2 stops
# 10672  DEL → AMD → BOM → COK    23:05  19:00 28 Jun  19h 55m     2 stops
# 10673  DEL → AMD → BOM → COK    13:25  04:25 28 May      15h     2 stops
#
#                    additional_info  ...  journey_year  journey_month  \
# 683                        No info  ...          2019              6
# 1061                       No info  ...          2019              5
# 1348                       No info  ...          2019              5
# 1418   In-flight meal not included  ...          2019              6
# 1674                       No info  ...          2019              3
# ...                            ...  ...           ...            ...
# 10594                      No info  ...          2019              6
# 10616                      No info  ...          2019              6
# 10634  In-flight meal not included  ...          2019              6
# 10672  In-flight meal not included  ...          2019              6
# 10673                      No info  ...          2019              5
#
#        journey_day  Arrival_hour  Arrival_min  Arrived_next_day  \
# 683              1             4           25              True
# 1061            21            19           15              True
# 1348            18            19           15              True
# 1418             6             4           25              True
# 1674            24            21           20             False
# ...            ...           ...          ...               ...
# 10594           27            12           35              True
# 10616            1            12           35              True
# 10634            6            12           35              True
# 10672           27            19            0              True
# 10673           27             4           25              True
#
#        duration_hours  duration_mins  Duration_in_mins weekday
# 683                13             50               830       5
# 1061               21             15              1275       1
# 1348               26              0              1560       5
# 1418               22             55              1375       3
# 1674                2             55               175       6
# ...               ...            ...               ...     ...
# 10594              13             30               810       3
# 10616              26             55              1615       5
# 10634              26             55              1615       3
# 10672              19             55              1195       3
# 10673              15              0               900       0
#
# [220 rows x 23 columns]

# %%
#drop duplicated rows
df.drop_duplicates(keep='first',inplace=True)

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Define a function to return arrival and departure hours as parts of the day

# %%
#define hours of the day
def ptday(x):
    if x>=00 and x<=4:
        return 'late night'
    elif x>4 and x<=8:
        return 'early morning'
    elif x>8 and x<=12:
        return 'morning'
    elif x>12 and x<=16:
        return 'After noon'
    elif x>16 and x<=20:
        return'evening'
    elif x>20 and x<=23:
        return 'night'

# %%
#apply the function to arrival hours and departure hours
df['arrival_period']=df['Arrival_hour'].apply(ptday)
df['departure_period']=df['dep_hour'].apply(ptday)

# %% [markdown]
# ## Drop redundant columns

# %%
#since we created new columns that extracted info from the following columns, we will drop them
df.drop(['Date_of_Journey'], axis=1, inplace=True)
df.drop(['Dep_Time'], axis=1, inplace=True)
df.drop('Arrival_Time', axis = 1, inplace = True)
# df.drop('duration_mins', axis = 1, inplace = True)
df.drop(['Duration'], axis=1, inplace=True)


#Route contains the name of cities and the number of stops. This info is already given in the Total_Stops and Destination and Source columns
#thus, we will drop Route
# df.drop(['Route'], axis=1, inplace=True)

# %%
df.head(10)
# Out:
#              Airline    Source Destination                  Route Total_Stops  \
# 0             IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1          Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2        Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3             IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4             IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
# 5           SpiceJet   Kolkata    Banglore              CCU → BLR    non-stop
# 6        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL      1 stop
# 7        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL      1 stop
# 8        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL      1 stop
# 9  Multiple carriers     Delhi      Cochin        DEL → BOM → COK      1 stop
#
#                additional_info  Price  dep_hour  dep_min  journey_year  ...  \
# 0                      No info   3898        22       20          2019  ...
# 1                      No info   7663         5       50          2019  ...
# 2                      No info  13883         9       25          2019  ...
# 3                      No info   6219        18        5          2019  ...
# 4                      No info  13303        16       50          2019  ...
# 5                      No info   3874         9        0          2019  ...
# 6  In-flight meal not included  11088        18       55          2019  ...
# 7                      No info  22271         8        0          2019  ...
# 8  In-flight meal not included  11088         8       55          2019  ...
# 9                      No info   8626        11       25          2019  ...
#
#    journey_day  Arrival_hour  Arrival_min  Arrived_next_day  duration_hours  \
# 0           24             1           10              True               2
# 1            1            13           15             False               7
# 2            9             4           25              True              19
# 3           12            23           30             False               5
# 4            1            21           35             False               4
# 5           24            11           25             False               2
# 6           12            10           25              True              15
# 7            1             5            5              True              21
# 8           12            10           25              True              25
# 9           27            19           15             False               7
#
#   duration_mins Duration_in_mins  weekday  arrival_period departure_period
# 0            50              170        6      late night            night
# 1            25              445        2      After noon    early morning
# 2             0             1140        6      late night          morning
# 3            25              325        6           night          evening
# 4            45              285        4           night       After noon
# 5            25              145        0         morning          morning
# 6            30              930        1         morning          evening
# 7             5             1265        4   early morning    early morning
# 8            30             1530        1         morning    early morning
# 9            50              470        0         evening          morning
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Rearrange and rename columns

# %% [markdown]
# **Renaming columns**

# %%
df.rename(columns={'Airline': "airline", 'Source':'embarked', 'Destination':'destination','Price':'price','Total_Stops':'stops'}, inplace=True)

# %% [markdown]
# **Rearranging columns**

# %%
df = df[['airline', 'embarked', 'destination', 'Route', 'stops',
       'journey_year',
       'journey_month', 'journey_day', 'weekday', 'dep_hour', 'dep_min', 'departure_period',  'Arrival_hour', 'Arrival_min', 'arrival_period',
       'Arrived_next_day',  'duration_hours', 'duration_mins',
       'Duration_in_mins',  'price' ,'additional_info']]

# %% [markdown]
# ## Save cleaned data to new file

# %%
df.to_csv("./df_cleaned.csv", index = False)

# %%
cleaned = pd.read_csv("./df_cleaned.csv")
cleaned
# Out:
#            airline  embarked destination                  Route     stops  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL  non-stop
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   2 stops
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK   2 stops
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    1 stop
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    1 stop
# ...            ...       ...         ...                    ...       ...
# 10457     Air Asia   Kolkata    Banglore              CCU → BLR  non-stop
# 10458    Air India   Kolkata    Banglore              CCU → BLR  non-stop
# 10459  Jet Airways  Banglore       Delhi              BLR → DEL  non-stop
# 10460      Vistara  Banglore   New Delhi              BLR → DEL  non-stop
# 10461    Air India     Delhi      Cochin  DEL → GOI → BOM → COK   2 stops
#
#        journey_year  journey_month  journey_day  weekday  dep_hour  ...  \
# 0              2019              3           24        6        22  ...
# 1              2019              5            1        2         5  ...
# 2              2019              6            9        6         9  ...
# 3              2019              5           12        6        18  ...
# 4              2019              3            1        4        16  ...
# ...             ...            ...          ...      ...       ...  ...
# 10457          2019              4            9        1        19  ...
# 10458          2019              4           27        5        20  ...
# 10459          2019              4           27        5         8  ...
# 10460          2019              3            1        4        11  ...
# 10461          2019              5            9        3        10  ...
#
#        departure_period Arrival_hour  Arrival_min  arrival_period  \
# 0                 night            1           10      late night
# 1         early morning           13           15      After noon
# 2               morning            4           25      late night
# 3               evening           23           30           night
# 4            After noon           21           35           night
# ...                 ...          ...          ...             ...
# 10457           evening           22           25           night
# 10458           evening           23           20           night
# 10459     early morning           11           20         morning
# 10460           morning           14           10      After noon
# 10461           morning           19           15         evening
#
#       Arrived_next_day  duration_hours  duration_mins  Duration_in_mins  \
# 0                 True               2             50               170
# 1                False               7             25               445
# 2                 True              19              0              1140
# 3                False               5             25               325
# 4                False               4             45               285
# ...                ...             ...            ...               ...
# 10457            False               2             30               150
# 10458            False               2             35               155
# 10459            False               3              0               180
# 10460            False               2             40               160
# 10461            False               8             20               500
#
#        price  additional_info
# 0       3898          No info
# 1       7663          No info
# 2      13883          No info
# 3       6219          No info
# 4      13303          No info
# ...      ...              ...
# 10457   4108          No info
# 10458   4146          No info
# 10459   7230          No info
# 10460  12649          No info
# 10461  11754          No info
#
# [10462 rows x 21 columns]
