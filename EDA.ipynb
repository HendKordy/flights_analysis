# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/flights.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional Info  10683 non-null  object
#  10  Price            10683 non-null  int64
#  11  Unnamed: 11      0 non-null      float64
#  12  Unnamed: 12      0 non-null      float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
df.sample(10)
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 2388          Air India      21/03/2019   Kolkata    Banglore
# 2115            Vistara      03/03/2019  Banglore   New Delhi
# 8314          Air India      12/06/2019    Mumbai   Hyderabad
# 8486        Jet Airways       9/06/2019     Delhi      Cochin
# 7636          Air India       9/05/2019    Mumbai   Hyderabad
# 8702  Multiple carriers      21/05/2019     Delhi      Cochin
# 9909             IndiGo      27/05/2019     Delhi      Cochin
# 1666        Jet Airways      21/04/2019  Banglore       Delhi
# 2637        Jet Airways      27/03/2019     Delhi      Cochin
# 874   Multiple carriers      27/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 2388              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 2115              BLR → DEL    19:40         22:20   2h 40m    non-stop
# ...

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional Info', 'Price', 'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
#the last 2 columns were added by mistake while converting xlsx file to csv, they contain only null values 
#so we can drop them 
df.drop(['Unnamed: 11', 'Unnamed: 12'], axis = 'columns', inplace =True )

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional Info', 'Price'],
#       dtype='object')
